# %%
import pandas as pd
import pandas_datareader as pdr
import matplotlib.pyplot as plt

# %%
#신풍제약
start_date = '2017-07-03'
end_date = '2020-10-31'
sinpung_weekly = pdr.get_data_yahoo('019170.ks', start_date, end_date, interval='w')

#변동성
sinpung_weekly['Volatility'] = (sinpung_weekly['High'] - sinpung_weekly['Low']) / sinpung_weekly['Low']

sinpung_weekly = sinpung_weekly.loc[:,['Close','Volume','Volatility']]
sinpung_weekly.tail(10)
# Out:
#              Close    Volume  Volatility
# Date
# 2020-08-23  111000  26272351    0.381937
# 2020-08-30  146000  28875293    0.455357
# 2020-09-06  153500  11223772    0.215385
# 2020-09-13  198000  16292334    0.360825
# 2020-09-20  136000  31568183    0.633588
# 2020-09-27  126500  11274606    0.290598
# 2020-10-04  140000  10330429    0.175510
# 2020-10-11  119000   8007915    0.206009
# 2020-10-18  139000  10655735    0.218487
# 2020-10-25  125500   5509264    0.157258
